# %%
import pandas as pd

# %%
paths = ['/code/data/data_1.csv',
         '/code/data/data_2.csv',
         '/code/data/data_3.csv',
         '/code/data/data_4.csv',
         '/code/data/data_5.csv',
         '/code/data/data_6.csv']

data = pd.DataFrame()

dfs = []
for path in paths:
    data_tmp = pd.read_csv(path)
    dfs.append(data_tmp)

data = pd.concat(dfs, ignore_index=True)
print('number of datapoints', len(data))
data.head()
# Out:
# number of datapoints 1203513
#    Unnamed: 0  terminaltime  soc  speed  totalodometer  chargestatus  \
# 0           0          56.0   68    5.0            2.1             3
# 1           1      493880.0   68   51.0            4.1             3
# 2           2      493890.0   68   50.9            4.3             3
# 3           3      493900.0   68   52.3            4.4             3
# 4           4      493910.0   67   60.0            4.6             3
#
#    totalvoltage  totalcurrent  minvoltagebattery  maxvoltagebattery  \
# 0         370.6           0.5              3.853              3.867
# 1         362.6         130.9              3.746              3.788
# 2         366.1          33.4              3.799              3.820
# 3         364.0          75.9              3.771              3.800
# 4         363.6         112.1              3.762              3.796
#
#    mintemperaturevalue  maxtemperaturevalue  \
# 0                   21                   23
# ...

# %%
print(data.columns.tolist())
# Out:
# ['Unnamed: 0', 'terminaltime', 'soc', 'speed', 'totalodometer', 'chargestatus', 'totalvoltage', 'totalcurrent', 'minvoltagebattery', 'maxvoltagebattery', 'mintemperaturevalue', 'maxtemperaturevalue', 'batteryvoltage', 'probetemperatures']
